# %% [markdown]
# <a href="https://colab.research.google.com/github/Esmielka/My_first_repository/blob/master/HomeWork_GameAnalytics_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
import random


print('-'*100)
print('Добро пожаловать в игру "Чудовищная вечеринка!"')
print('-'*100)

# введение, определяем количество и имена игроков
sleep(2)
print('На дворе Хэллоуин, и Вы с друзьями в замечательных костюмах отправились бродить по городу, чтобы повеселиться!')
sleep(2)
lst_gamers=list(input('Кто отправился в наше незабываемое путешествие? Как вас зовут? Допустимое количество игроков от 2-х до 5 человек. Введите имена игроков через пробел: ').split())
numb=len(lst_gamers)
if numb > 5:
  print('Вас слишком много! У нас не хватит места!')
###if numb == 1:
###  print('Что-то Вас отвлекло, друзья ушли, и Вы остались наедине с ночным городом, наполненным людьми в странных костюмах! Но только ли людьми?')
###  sleep(3)
###  print('Вам надоело бродить одному, да и чего уж, стало изрядно не по себе... И Вы увидели симпатичный бар, в котором явно весело отмечают праздник!')
if numb > 1 and numb < 6:
  print('Вы весело погуляли и даже добыли конфет! Но в какой-то момент неприятное чуство взгляда в спину заставило каждого из вас оглянуться...')
  sleep(3)
  print('Только ли люди окружают вас в этой веселой городской ночи? Вам стало изрядно не по себе! И Вы увидели симпатичный бар, в котором явно весело отмечают праздник!')
print('Вы, само собой, решили присоединиться!')
sleep(2)
print('Вы открываете дверь...')
sleep(2)
print('-'*100)
print('А внутри веселый праздник, к которому Вы с радостью присоединяетесь! Вы танцуете и вечелитесь, но...')
sleep(2)
print('В один страшный момент понимаете, что вокруг...', end='', flush=True)
sleep(2)
print('не люди!')
sleep(2)
print('Вас окружают настоящие Джеки-с-фонарем, Скелетоны, Гоблины, Ведьмы и Зомби, стайки Оборотней, Вампиры и даже Демоны!!!')
sleep(2)
print('И они смотрят на вас голодными глазами!')
sleep(2)
print('Вы для них - изысканное лакомство!')
sleep(2)
print('Но что же делать!')
print('И вот они понимают, что раскрыты, и....')
sleep(4)
print('Молодая ведьмочка предлагает Вам сыграть в карты, а ставкой в этой игре будете Ваша свобода!')

# правила
print('Правила просты. Вам раздают карты. Всего в игре 3 раунда. В начале каждого раунда игроки смотрят каждый свои карты и выбирают одну карту из своей руки. Кладут её перед собой рубашкой вверх.')
print('Когда все готовы, игроки одновременно переворачивают свою выбранную карту, а оставшиеся в руке карты передают соседу.')
print('И так каждый ход, пока у игроков не закончатся карты. Прийдет пора подсчета очков:')
print('Каждая карта обозначает монстра! У нас есть Стайки оборотней из 3-х, 6-ти или 9-х оборотней. В конце каждого раунда Игрок подсчитывает количество у него оборотней. Тот, у кого будет их больше всего - получает 6 очков.')
print('Тот, кто займет второе место получит 4 балла.')
print('Каждые 2 Скелетона принесут Вам 5 очков. Каждые 3 Зомби - 10 очков. Каждый Гоблин принесет 1 очко, каждый Вампир - 2 очка, а каждый Демон - 3.')
print('Чем больше Ведьм, тем большое очков! За одну Вы получаете 1 очко, за 2 - 3 очка, за 3 - 5 очков, за 4 - 9, а за 5 - 14!')
print('В конце игры подсчитываем, сколько у Вас было Джеков-с-фонарем. Тот, у кого больше всех - получит дополнительные 6 баллов, а у того у кого меньше всех - эти 6 баллов отнимут!')

input('Вы готовы?!?!')
print('-'*100)
deck=['Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Гоблин', 'Гоблин', 'Гоблин', 'Гоблин', 'Вампир', 'Вампир', 'Демон', 'Демон', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем']
deck_1=['Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Гоблин', 'Гоблин', 'Гоблин', 'Гоблин', 'Вампир', 'Вампир', 'Демон', 'Демон', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем']
deck_2=['Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 3-х особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 6-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Стайка оборотней из 9-ти особей', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Ведьма', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Скелетон', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Зомби', 'Гоблин', 'Гоблин', 'Гоблин', 'Гоблин', 'Вампир', 'Вампир', 'Демон', 'Демон', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем', 'Джек-с-Фонарем']
points_i=[]
hod_n=[]
hod_n2=[]
hod_n3=[]

def curds(deck_r):
  #раздаем карты
  card_for_game=[]
  card_for_game_1=[]
  for i in range(numb):
    card_for_game=random.sample(deck_r, k=7)   #рандомно раздаем карты
    for j in range(len(card_for_game)):
      deck_r.remove(card_for_game[j])
    card_for_game_1.append(card_for_game)
  for i in range(numb):
    print(f'{lst_gamers[i]}, Ваши карты на этот раунд: {card_for_game_1[i]}')  # что раздали
  return card_for_game_1

def raund(card_for_game_1):
  # играем раунд
  print('Посмотрите карты и выберите, что положить на стол! Каждый игрок, введите номер карты!')
  hod_n=[]
  s=[]
  for i in range(numb):
    sc=len(card_for_game_1[i])
    s.append(sc)
  step=max(s)
  while step > 0: 
    hod_1=[]
    for i in range(numb):
      if len(card_for_game_1[i]) > 0:
        if len(card_for_game_1[i]) > 1:
          h=int(input(f'{lst_gamers[i]}, Ваш выбор: '))-1
          if h < len(card_for_game_1[i]):
            hod_1.append(card_for_game_1[i][h])
            print(card_for_game_1[i][h])
            card_for_game_1[i].remove(card_for_game_1[i][h])
          else:
            print('Вы ввели неверное значение! Попробуйте еще раз!')
            h=int(input(f'{lst_gamers[i]}, Ваш выбор: '))-1
            if h < len(card_for_game_1[i]):
              hod_1.append(card_for_game_1[i][h])
              print(card_for_game_1[i][h])
              card_for_game_1[i].remove(card_for_game_1[i][h])
            else:
              hod_1.append(0)
              print('Вы получаете 0 баллов за этот ход!')   
        else:
          print(f'Ваш последний ход {card_for_game_1[i]}')
          hod_1.append(card_for_game_1[i][0])
          card_for_game_1[i].remove(card_for_game_1[i][0]) 
      else:
        hod_1.append(0)
        print('Вы получаете 0 баллов за этот ход!')
    hod_n.append(hod_1)
    #передаем карты соседу
    card_for_game_2=card_for_game_1
    card_for_game_1=[]
    for i in range(len(card_for_game_2)):
      card_for_game_1.append(card_for_game_2[i-1])
      if card_for_game_1[i] != []:
        print(f'Карты {lst_gamers[i]} на этот ход: {card_for_game_1[i]}')
    #считаем число ходов
    s=[]
    for i in range(numb):
      sc=len(card_for_game_1[i])
      s.append(sc)
    step=max(s)
  return(hod_n)  

def points_k(hod_n): #подсчет очков
  points=[]
  ob_os=[]   # список стаек оборотней у каждого игрока
  ob_oss=[]  # список количества голов оборотней у каждого игрока
  v_os=[]   # список Ведьм у каждого игрока
  v_oss=[]  # список количества Ведьм у каждого игрока
  gob_os=[]   # список гоблинов у каждого игрока
  gob_oss=[]  # список количества гоблинов у каждого игрока
  vamp_os=[]   # список вампиров у каждого игрока
  vamp_oss=[]  # список количества вампиров у каждого игрока
  dem_os=[]   # список демонов у каждого игрока
  dem_oss=[]  # список количества демонов у каждого игрока
  skel_os=[]   # список скелетонов у каждого игрока
  skel_oss=[]  # список количества скелетонов у каждого игрока
  zomb_os=[]   # список зомби у каждого игрока
  zomb_oss=[]  # список количества зомби у каждого игрока
  # считаем карты 
  for i in range(numb):
    ob_os.append([])
    v_os.append([])
    gob_os.append([])
    vamp_os.append([])
    dem_os.append([])
    skel_os.append([])
    zomb_os.append([])
    for j in range(len(hod_n)):
      if hod_n[j][i] == 'Стайка оборотней из 9-ти особей':
        ob_os[i].append(9)
      elif hod_n[j][i] == 'Стайка оборотней из 3-х особей':
        ob_os[i].append(3)
      elif hod_n[j][i] == 'Стайка оборотней из 6-ти особей':
        ob_os[i].append(6)
      elif hod_n[j][i] == 'Ведьма':
        v_os[i].append(1)
      elif hod_n[j][i] == 'Гоблин':
        gob_os[i].append(1)
      elif hod_n[j][i] == 'Вампир':
        vamp_os[i].append(1)
      elif hod_n[j][i] == 'Демон':
        dem_os[i].append(1)
      elif hod_n[j][i] == 'Скелетон':
        skel_os[i].append(1)
      elif hod_n[j][i] == 'Зомби':
        zomb_os[i].append(1)
    summ_ob=sum(ob_os[i])
    ob_oss.append(summ_ob)
    summ_v=sum(v_os[i])
    v_oss.append(summ_v)
    summ_gob=sum(gob_os[i])
    summ_vamp=sum(vamp_os[i])
    summ_dem=sum(dem_os[i])
    gob_oss.append(summ_gob)
    vamp_oss.append(summ_vamp)
    dem_oss.append(summ_dem)
    summ_skel=sum(skel_os[i])
    summ_zomb=sum(zomb_os[i])
    skel_oss.append(summ_skel)
    zomb_oss.append(summ_zomb)
  # подсчет очков по оборотням, меняем список ob_oss на список с очками
  sort_ob_oss=sorted(ob_oss)
  if sort_ob_oss[-1]==sort_ob_oss[-2]:
    for i in range(numb):
      if ob_oss[i] == sort_ob_oss[-1]:
        ob_oss[i]=6
      else:
        ob_oss[i]=0
  else:
    for i in range(numb):
      if ob_oss[i] == sort_ob_oss[-1]:
        ob_oss[i]=6
      elif ob_oss[i] == sort_ob_oss[-2]:
        ob_oss[i]=4
      else:
        ob_oss[i]=0
  # подсчет очков по ведьмам, меняем список v_oss на список с очками
  for i in range(numb):
    if v_oss[i] == 1:
      v_oss[i]=1
    elif v_oss[i] == 2:
      v_oss[i]=3
    elif v_oss[i] == 3:
      v_oss[i]=5
    elif v_oss[i] == 4:
      v_oss[i]=9
    elif v_oss[i] == 5:
      v_oss[i]=14
    elif v_oss[i] == 0:
      v_oss[i]=0
  # подсчет очков по гоблинам/вампирам/демонам, меняем список ..._oss на список с очками
  for i in range(numb):
    vamp_oss[i]=vamp_oss[i]*2
    dem_oss[i]=dem_oss[i]*3  
  # подсчет очков по гоблинам/вампирам/демонам, меняем список ..._oss на список с очками
  for i in range(numb):
    skel_oss[i]=(skel_oss[i]//2)*5
    zomb_oss[i]=(zomb_oss[i]//3)*10  
  #итоговые баллы за раунд
  for i in range(numb):
    points.append([])
    points[i]=ob_oss[i]+v_oss[i]+gob_oss[i]+vamp_oss[i]+dem_oss[i]+skel_oss[i]+zomb_oss[i]
  for i in range(numb):
    print(f'{lst_gamers[i]}, Ваши баллы за этот раунд: {points[i]}')  # подвели итог
  return points

print('1 раунд!')
card_for_game_n=curds(deck)
hod_n=raund(card_for_game_n)   #запускаем 1 раунд
points=points_k(hod_n)
points_i.append(points)

print('-'*100)
print('2 раунд!')
card_for_game_2=curds(deck_1)
hod_n2=raund(card_for_game_2)   #запускаем 2 раунд
points=points_k(hod_n2)
points_i.append(points)

print('-'*100)
print('3 раунд!')
card_for_game_3=curds(deck_2)
hod_n3=raund(card_for_game_3)   #запускаем 3 раунд
points=points_k(hod_n3)
points_i.append(points)

print('-'*100)
#джеки-с-фонарями
djeck_os=[]
djeck_oss=[]
for i in range(numb):
  djeck_os.append([])
  for j in range(len(hod_n)):
    if hod_n[j][i] == 'Джек-с-Фонарем':
      djeck_os[i].append(1)
  for j in range(len(hod_n2)):
    if hod_n2[j][i] == 'Джек-с-Фонарем':
      djeck_os[i].append(1)
  for j in range(len(hod_n3)):
    if hod_n3[j][i] == 'Джек-с-Фонарем':
      djeck_os[i].append(1)
  summ_djeck=sum(djeck_os[i])
  djeck_oss.append(summ_djeck)
sort_djeck=sorted(djeck_oss)
for i in range(numb):
  if djeck_oss[i] == sort_djeck[-1]:
    djeck_oss[i]=6
  elif djeck_oss[i] == sort_djeck[0]:
    djeck_oss[i]=-6
  else:
    djeck_oss[i]=0
print(f'Подсчитаем очки за Джека-с-фонарем!')
for i in range(numb):
  print(f'{lst_gamers[i]}, Ваши баллы за Джека: {djeck_oss[i]}')

print('-'*100)
result=[]
for i in range(numb):
  result_123=points_i[0][i]+points_i[1][i]+points_i[2][i]+djeck_oss[i]
  result.append(result_123)
print('Итак, Ваши результаты!')
for i in range(numb):
  print(f'{lst_gamers[i]}, Ваш результат: {result[i]}.')
print('-'*100)  
result_1=max(result)
sort_result=sorted(result)
vikt=[]
for i in range(numb):
  if result[i] == sort_result[-1]:
    vikt.append(lst_gamers[i])
if len(vikt)==1:
  print(f'{vikt[0]}, ты победил!')
  print('Свободен! Оставшиеся - рюмку крови на всех...')
else:
  print(f'Вы победили: ')
  print(vikt, sep=' и', end='!')
  print('Свободны! Оставшиеся - рюмку крови на всех...')
# Out:
# ----------------------------------------------------------------------------------------------------
# Добро пожаловать в игру "Чудовищная вечеринка!"
# ----------------------------------------------------------------------------------------------------
# На дворе Хэллоуин, и Вы с друзьями в замечательных костюмах отправились бродить по городу, чтобы повеселиться!
# Кто отправился в наше незабываемое путешествие? Как вас зовут? Допустимое количество игроков от 2-х до 5 человек. Введите имена игроков через пробел: 1 2 3 4
# Вы весело погуляли и даже добыли конфет! Но в какой-то момент неприятное чуство взгляда в спину заставило каждого из вас оглянуться...
# Только ли люди окружают вас в этой веселой городской ночи? Вам стало изрядно не по себе! И Вы увидели симпатичный бар, в котором явно весело отмечают праздник!
# Вы, само собой, решили присоединиться!
# Вы открываете дверь...
# ----------------------------------------------------------------------------------------------------
# ...
