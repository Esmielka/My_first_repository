# %% [markdown]
# <a href="https://colab.research.google.com/github/Esmielka/My_first_repository/blob/master/Control_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FOLDER = "КТ" # Тут имя папки, в которую все сохраняется.

PATH = "drive/MyDrive/" + FOLDER  + "/"
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append(PATH)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

my_list = []              #вводим список для данных из файл
with open(PATH + 'innov.txt', 'r', encoding='utf-8-sig') as f1:    #открываем файл
  for line in f1:
    my_list.append(line.split(','))                                #формируем список с вложенными списками, разделитель (,)

number = len(my_list)      # количество регионов, по которым предоставлены данные
patent_yes=[]              # список с перечнем количества одобренных заявок на патенты по стране в целом
patent_pov_fo=[]           # отдельный список с вложениями по Приволжскому федеральному округу
perm_patent=[]             # отдельный список по Пермскому краю
patent_yes_centr_fo=[]     # список, одобренные заявки на патент по Центральному федеральному округу
patent_yes_sevz_fo=[]      # список, одобренные заявки на патент по Северо-Западному федеральному округу
patent_yes_uz_fo=[]        # список, одобренные заявки на патент по Южному федеральному округу
patent_yes_sevkav_fo=[]    # список, одобренные заявки на патент по Северо-Кавказскому федеральному округу
patent_yes_pov_fo=[]       # список, одобренные заявки на патент по Приволжскому федеральному округу
patent_yes_ur_fo=[]        # список, одобренные заявки на патент по Уральскому федеральному округу
patent_yes_sib_fo=[]       # список, одобренные заявки на патент по Сибирскому федеральному округу
patent_yes_dalvost_fo=[]   # список, одобренные заявки на патент по Дальневосточному федеральному округу
part_yes_centr_fo=[]       # список, доля одобрений на заявки на патент по Центральному федеральному округу
part_yes_sevz_fo=[]        # список, доля одобрений на заявки на патент по Северо-Западному федеральному округу
part_yes_uz_fo=[]          # список, доля одобрений на заявки на патент по Южному федеральному округу
part_yes_sevkav_fo=[]      # список, доля одобрений на заявки на патент по Северо-Кавказскому федеральному округу
part_yes_pov_fo=[]         # список, доля одобрений на заявки на патент по Приволжскому федеральному округу
part_yes_ur_fo=[]          # список, доля одобрений на заявки на патент по Уральскому федеральному округу
part_yes_sib_fo=[]         # список, доля одобрений на заявки на патент по Сибирскому федеральному округу
part_yes_dalvost_fo=[]     # список, доля одобрений на заявки на патент по Дальневосточному федеральному округу

# ввожу списки федеральных округов с наименованием входящих в них регионов
centr_fo=['г. Москва', 'Белгородская область', 'Брянская область', 'Владимирская область', 'Воронежская область', 'Ивановская область', 'Калужская область', 'Костромская область', 'Курская область', 'Липецкая область', 'Московская область', 'Орловская область', 'Рязанская область', 'Смоленская область', 'Тамбовская область', 'Тверская область', 'Тульская область', 'Ярославская область' ]
sevz_fo=['г. Санкт-Петербург', 'Республика Карелия', 'Республика Коми', 'Архангельская область', 'Вологодская область', 'Калинингpадская область', 'Ленинградская область', 'Мурманская область', 'Новгородская область', 'Псковская область', 'Ненецкий автономный округ' ]
uz_fo=['Ростовская область', 'Республика Адыгея', 'Республика Калмыкия', 'Республика Крым', 'Краснодарский край', 'Астраханская область', 'Волгоградская область', 'г. Севастополь' ]
sevkav_fo=['Ставропольский край', 'Республика Дагестан', 'Республика Ингушетия', 'Кабардино-Балкарская Республика', 'Карачаево-Черкесская Республика', 'Республика Северная Осетия - Алания', 'Чеченская Республика' ]
pov_fo=['Нижегородская область', 'Республика Башкортостан', 'Республика Марий Эл', 'Республика Мордовия', 'Республика Татарстан', 'Удмуртская Республика', 'Чувашская Республика', 'Пермский край', 'Кировская область', 'Оренбургская область', 'Пензенская область', 'Самарская область', 'Саратовская область', 'Ульяновская область' ]
ur_fo=['Свердловская область', 'Курганская область', 'Тюменская область', 'Челябинская область', 'Ханты - Мансийский автономный округ - Югра', 'Ямало - Ненецкий автономный округ' ]
sib_fo=['Новосибирская область', 'Республика Алтай', 'Республика Тыва', 'Республика Хакасия', 'Алтайский край', 'Красноярский край', 'Иркутская область', 'Кемеровская область', 'Омская область', 'Томская область' ]
dalvost_fo=['Приморский край', 'Республика Бурятия', 'Республика Саха (Якутия)', 'Забайкальский край', 'Камчатский край', 'Хабаровский край', 'Амурская область', 'Магаданская область', 'Сахалинская область', 'Еврейская автономная область', 'Чукотский автономный округ' ]

for i in range(len(my_list)):
  my_list[i][1] = int(my_list[i][1])      # изменяем строчные значения на цифры
  my_list[i][2] = int(my_list[i][2])
  if my_list[i][1]==0:
    part_stolbec=0                       # делить на 0 нельзя, поэтому вот так
  else:
    part_stolbec=int(round(my_list[i][2]/my_list[i][1]*100, 0))
    if part_stolbec >= 100:              # в некоторых регионах количество одобренных заявок на патент выше, чем количество поданных. Очевидно попадают заявки из прошлого периода. Поэтому просто приравниваем к 100%-му одобрению
      part_stolbec=100
  my_list[i].append(part_stolbec)        # добавляем 5 столбец (индекс 4) с расчетным значением доли одобренных патентов

# сбор списка количества одобренных патентов и доли одобренных патентов по федеральным округам
for i in range(len(my_list)):
  if my_list[i][0] in centr_fo:
    my_list[i][3] = 'Центральный федеральный округ'    # присваиваем "техническому", не несущему информационной нагрузки, стобцу 4 (индекс 3) - значение федерального округа
    patent_yes_centr_fo.append(my_list[i][2])
    part_yes_centr_fo.append(my_list[i][4])
  elif my_list[i][0] in sevz_fo:
    my_list[i][3] = 'Северо-Западный федеральный округ'
    patent_yes_sevz_fo.append(my_list[i][2])
    part_yes_sevz_fo.append(my_list[i][4])
  elif my_list[i][0] in uz_fo:
    my_list[i][3] = 'Южный федеральный округ'
    patent_yes_uz_fo.append(my_list[i][2])
    part_yes_uz_fo.append(my_list[i][4])
  elif my_list[i][0] in sevkav_fo:
    my_list[i][3] = 'Северо-Кавказский федеральный округ'
    patent_yes_sevkav_fo.append(my_list[i][2])
    part_yes_sevkav_fo.append(my_list[i][4])
  elif my_list[i][0] in pov_fo:
    my_list[i][3] = 'Приволжский федеральный округ'
    patent_yes_pov_fo.append(my_list[i][2])
    patent_pov_fo.append(my_list[i])
    part_yes_pov_fo.append(my_list[i][4])
  elif my_list[i][0] in ur_fo:
    my_list[i][3] = 'Уральский федеральный округ'
    patent_yes_ur_fo.append(my_list[i][2])
    part_yes_ur_fo.append(my_list[i][4])
  elif my_list[i][0] in sib_fo:
    my_list[i][3] = 'Сибирский федеральный округ'
    patent_yes_sib_fo.append(my_list[i][2])
    part_yes_sib_fo.append(my_list[i][4])
  elif my_list[i][0] in dalvost_fo:
    my_list[i][3] = 'Дальневосточный федеральный округ'
    patent_yes_dalvost_fo.append(my_list[i][2])
    part_yes_dalvost_fo.append(my_list[i][4])
  else:
    my_list[i][3] = 'ВНИМАНИЕ'              # для проверки на наличие разночтений в названии региона

for i in range(len(my_list)):
  patent_yes.append(my_list[i][2])   # сбор списка количества одобренных патентов по стране 
  if 'Пермский край' in my_list[i][0]:   # формирование отедльнго списка по Пермскому краю
    perm_patent=my_list[i]  

# расчет характеристик федеральных округов: максильное число одобренных патентов
max_patent=max(patent_yes)   #максимум по стране
max_patent_patent_yes_centr_fo=max(patent_yes_centr_fo)
max_patent_patent_yes_sevz_fo=max(patent_yes_sevz_fo)
max_patent_patent_yes_uz_fo=max(patent_yes_uz_fo)
max_patent_patent_yes_sevkav_fo=max(patent_yes_sevkav_fo)
max_patent_patent_yes_pov_fo=max(patent_yes_pov_fo)
max_patent_patent_yes_ur_fo=max(patent_yes_ur_fo)
max_patent_patent_yes_sib_fo=max(patent_yes_sib_fo)
max_patent_patent_yes_dalvost_fo=max(patent_yes_dalvost_fo)

# расчет характеристик федеральных округов: среднее число одобренных патентов
sredn_patent=int(round(sum(patent_yes)/number,0))   #среднее по стране
sredn_patent_patent_yes_centr_fo=int(round(sum(patent_yes_centr_fo)/len(patent_yes_centr_fo),0))
sredn_patent_patent_yes_sevz_fo=int(round(sum(patent_yes_sevz_fo)/len(patent_yes_sevz_fo),0))
sredn_patent_patent_yes_uz_fo=int(round(sum(patent_yes_uz_fo)/len(patent_yes_uz_fo),0))
sredn_patent_patent_yes_sevkav_fo=int(round(sum(patent_yes_sevkav_fo)/len(patent_yes_sevkav_fo),0))
sredn_patent_patent_yes_pov_fo=int(round(sum(patent_yes_pov_fo)/len(patent_yes_pov_fo),0))
sredn_patent_patent_yes_ur_fo=int(round(sum(patent_yes_ur_fo)/len(patent_yes_ur_fo),0))
sredn_patent_patent_yes_sib_fo=int(round(sum(patent_yes_sib_fo)/len(patent_yes_sib_fo),0))
sredn_patent_patent_yes_dalvost_fo=int(round(sum(patent_yes_dalvost_fo)/len(patent_yes_dalvost_fo),0))

# расчет характеристик федеральных округов: средняя доля одобрения патентов
sredn_part_yes=int(round((sum(part_yes_centr_fo)+sum(part_yes_sevz_fo)+sum(part_yes_uz_fo)+sum(part_yes_sevkav_fo)+sum(part_yes_pov_fo)+sum(part_yes_dalvost_fo)+sum(part_yes_sib_fo)+sum(part_yes_ur_fo))/number,0))   #среднее по стране
sredn_part_yes_centr_fo=int(round(sum(part_yes_centr_fo)/len(part_yes_centr_fo),0))
sredn_part_yes_sevz_fo=int(round(sum(part_yes_sevz_fo)/len(part_yes_sevz_fo),0))
sredn_part_yes_uz_fo=int(round(sum(part_yes_uz_fo)/len(part_yes_uz_fo),0))
sredn_part_yes_sevkav_fo=int(round(sum(part_yes_sevkav_fo)/len(part_yes_sevkav_fo),0))
sredn_part_yes_pov_fo=int(round(sum(part_yes_pov_fo)/len(part_yes_pov_fo),0))
sredn_part_yes_ur_fo=int(round(sum(part_yes_ur_fo)/len(part_yes_ur_fo),0))
sredn_part_yes_sib_fo=int(round(sum(part_yes_sib_fo)/len(part_yes_sib_fo),0))
sredn_part_yes_dalvost_fo=int(round(sum(part_yes_dalvost_fo)/len(part_yes_dalvost_fo),0))

# ввожу новый список со вложенными списками с характеристиками федеральных округов: наименование, максильное число одобренных патентов, среднее число одобренных патентов, средняя доля одобрения патентов
fo=[['Центральный федеральный округ', max_patent_patent_yes_centr_fo, sredn_patent_patent_yes_centr_fo, sredn_part_yes_centr_fo], ['Северо-Западный федеральный округ', max_patent_patent_yes_sevz_fo, sredn_patent_patent_yes_sevz_fo, sredn_part_yes_sevz_fo], ['Южный федеральный округ', max_patent_patent_yes_uz_fo, sredn_patent_patent_yes_uz_fo, sredn_part_yes_uz_fo], ['Северо-Кавказский федеральный округ', max_patent_patent_yes_sevkav_fo, sredn_patent_patent_yes_sevkav_fo, sredn_part_yes_sevkav_fo], ['Приволжский федеральный округ', max_patent_patent_yes_pov_fo, sredn_patent_patent_yes_pov_fo, sredn_part_yes_pov_fo], ['Уральский федеральный округ', max_patent_patent_yes_ur_fo, sredn_patent_patent_yes_ur_fo, sredn_part_yes_ur_fo], ['Сибирский федеральный округ', max_patent_patent_yes_sib_fo, sredn_patent_patent_yes_sib_fo, sredn_part_yes_sib_fo], ['Дальневосточный федеральный округ', max_patent_patent_yes_dalvost_fo, sredn_patent_patent_yes_dalvost_fo, sredn_part_yes_dalvost_fo]]

# сортировки
for i in range(len(fo)):
  sort_fo_sredn = sorted(fo, key = lambda k : k[2], reverse=True)
  sort_fo_part = sorted(fo, key = lambda k : k[3], reverse=True)
for i in range(len(my_list)):
  sort_list = sorted(my_list, key = lambda k : k[1], reverse=True)
for i in range(len(sort_list)):
  sort_part_list = sorted(sort_list, key = lambda k : k[4], reverse=True)
for i in range(len(patent_pov_fo)):
  sort_patent_yes_pov_fo = sorted(patent_pov_fo, key = lambda k : k[2], reverse=True)
for i in range(len(sort_patent_yes_pov_fo)):
  sort_patent_pov_fo_part = sorted(sort_patent_yes_pov_fo, key = lambda k : k[4], reverse=True)

# элементы для написания выводов - оценка уровня по стране
if perm_patent[2]>sredn_patent:
  yroven='выше среднего уровня'
elif perm_patent[2]==sredn_patent:
  yroven='на среднем уровне'
else:
  yroven='ниже среднего уровня'

for i in range(len(sort_list)):
  if 'Пермский край' in sort_list[i][0]:
    perm_range=i+1

if perm_patent[2]>sredn_part_yes:
  yroven_part='выше среднего уровня'
elif perm_patent[2]==sredn_part_yes:
  yroven_part='на среднем уровне'
else:
  yroven_part='ниже среднего уровня'

for i in range(len(sort_part_list)):
  if 'Пермский край' in sort_part_list[i][0]:
    perm_part_range=i+1

# элементы для написания выводов - оценка уровня по региону по количеству выданных патентов
if perm_patent[2]>sredn_patent_patent_yes_pov_fo:
  yroven_fo='выше среднего уровня'
elif perm_patent[2]==sredn_patent_patent_yes_pov_fo:
  yroven_fo='на среднем уровне'
else:
  yroven_fo='ниже среднего уровня'

for i in range(len(sort_patent_yes_pov_fo)):
  if 'Пермский край' in sort_patent_yes_pov_fo[i][0]:
    perm_range_fo=i+1

# элементы для написания выводов - оценка уровня по региону по доле одобрения заявок
if perm_patent[4]>sredn_part_yes_pov_fo:
  yroven_part_fo='выше среднего уровня'
elif perm_patent[4]==sredn_part_yes_pov_fo:
  yroven_part_fo='на среднем уровне'
else:
  yroven_part_fo='ниже среднего уровня'

for i in range(len(sort_patent_pov_fo_part)):
  if 'Пермский край' in sort_patent_pov_fo_part[i][0]:
    perm_range_part_fo=i+1

#для диаграмм
fo_yes_sredn=[]
fo_sredn_part=[]
for i in range(len(sort_fo_sredn)):
  fo_sredn_part.append(sort_fo_sredn[i][3])     #отсортированный список средней доли одобренных заявок на патент по фед. округам
  fo_yes_sredn.append(sort_fo_sredn[i][2])     #отсортированный список среднего количества одобренных заявок на патент по фед. округам
inex=['ЦФО', 'ПФО', 'СЗФО', 'СФО', 'УФО', 'ЮФО', 'СКФО', 'ДФО']

priv_yes_sredn=[]
priv_sredn_part=[]
priv_name=[]
for i in range(len(sort_patent_yes_pov_fo)):
  priv_sredn_part.append(sort_patent_yes_pov_fo[i][4])     #отсортированный список средней доли одобренных заявок на патент по Приволжскому фед. округу
  priv_name.append(sort_patent_yes_pov_fo[i][0])     #отсортированный список наименований по Приволжскому фед. округу
  priv_yes_sredn.append(sort_patent_yes_pov_fo[i][2])     #отсортированный список среднего количества одобренных заявок на патент по Приволжскому фед. округу

# вывод результатов
n=0
print('Рейтинг регионов России по количеству выданных патентов:')
print('-'*100)
for region in sort_list:
  n+=1
  if region[1]!=0:
    part=int(round(region[2]/region[1]*100, 0))
    if part >= 100:
      part_yes='Доля одобренных заявок: 100%'
    else:
      part_yes='Доля одобренных заявок: '+ str(part) + '%'
  else:
    part_yes='Заявки не подавались'
  print(f'{n}. {region[0]}, количество выданных патентов: {region[2]}. {part_yes}')   # можно оптимизировать, но мне нравится так :-)
print('-'*100)

n1=0
print('Рейтинг регионов Приволжского федерального округа по количеству выданных патентов:')
print('-'*100)
for region in sort_patent_yes_pov_fo:
  n1+=1
  print(f'{n1}. {region[0]}, количество выданных патентов: {region[2]}. Доля одобренных патентов: {region[4]}%.')
print(f'ИТОГО: Среднее количество выданных патентов по Приволжскому федеральному округу: {sredn_patent_patent_yes_pov_fo}. Доля одобренных патентов по округу: {sredn_part_yes_pov_fo}%')
barrasp2=sns.barplot(x=priv_yes_sredn, y=priv_name, palette='ch:s=-.2,r=.6')
barrasp2.axes.set_title('Распределение регионов Приволжского федерального округа', fontsize=16)
barrasp2.set_xlabel("Кол-во выданных патентов", fontsize=10)
plt.show();
print('-'*100)

n2=0
print('Рейтинг регионов Приволжского федерального округа по доле одобрения заявок на патент:')
print('-'*100)
for region in sort_patent_pov_fo_part:
  n2+=1
  print(f'{n2}. {region[0]}, доля одобрения заявок на патент: {region[4]}%. Количество выданных патентов: {region[2]}.')
print(f'ИТОГО: Доля одобренных заявок на патент по округу: {sredn_part_yes_pov_fo}%. Среднее количество выданных патентов по Приволжскому федеральному округу: {sredn_patent_patent_yes_pov_fo}.')
barrasp3=sns.barplot(x=priv_sredn_part, y=priv_name, palette='icefire')
barrasp3.axes.set_title('Распределение регионов Приволжского федерального округа', fontsize=16)
barrasp3.set_xlabel("Доля одобрения заявок, %", fontsize=10)
plt.show();
print('-'*100)

k=0
print('Рейтинг федеральных округов России по среднему количеству выданных патентов:')
print('-'*100)
for region in sort_fo_sredn:
  k+=1
  print(f'{k}. {region[0]}, среднее количество выданных патентов: {region[2]}. Максимальное количество выданных патентов среди регионов округа: {region[1]}. Средняя доля одобренных патентов: {region[3]}%.')
print(f'ИТОГО: Среднее количество выданных патентов по России: {sredn_patent}. Максимальное количество выданных патентов по России: {max_patent}. Средняя доля одобренных патентов: {sredn_part_yes}%.')
barrasp=sns.barplot(x=inex, y=fo_yes_sredn, palette='viridis')
barrasp.axes.set_title('Распределение федеральных округов России', fontsize=16)
barrasp.set_xlabel("Федеральные округа", fontsize=10)
barrasp.set_ylabel("Среднее кол-во выданных патентов", fontsize=10)
plt.show();
print('-'*100)

z=0
print('Рейтинг федеральных округов России по средней доле одобренных патентов:')
print('-'*100)
for region in sort_fo_part:
  z+=1
  print(f'{z}. {region[0]}, средняя доля одобренных патентов: {region[3]}%.')
print(f'ИТОГО: Средняя доля одобренных патентов по России: {sredn_part_yes}%.')
barrasp1=sns.barplot(x=inex, y=fo_sredn_part, palette='rocket')
barrasp1.axes.set_title('Распределение федеральных округов России', fontsize=16)
barrasp1.set_xlabel("Федеральные округа", fontsize=10)
barrasp1.set_ylabel("Доля одобрения заявок, %", fontsize=10);
plt.show();
print('-'*100)

print('ВЫВОДЫ:')
print(f'Нам предоставлены данные по {number} регионам, а значит по всем субъектам РФ.')
print(f'В Пермском крае одобрено {perm_patent[2]} патентов. Это {perm_patent[4]}% от общего количества поданных заявок.')
print(f'Количество выданных патентов в Пермском крае {yroven_fo} по федеральному округу и {yroven} по стране. По данному показателю он занимает {perm_range_fo} место в рейтинге регионов по федеральному округу и {perm_range} место по стране.')
print(f'Доля одобрения заявок на патент в Пермском крае {yroven_part_fo} по федеральному округу и {yroven_part} по стране. По данному показателю он занимает {perm_range_part_fo} место в рейтинге регионов по федеральному округу и {perm_part_range} место по стране.')
print('-'*100)
# Out:
# Рейтинг регионов России по количеству выданных патентов:
# ----------------------------------------------------------------------------------------------------
# 1. г. Москва, количество выданных патентов: 4510. Доля одобренных заявок: 86%
# 2. г. Санкт-Петербург, количество выданных патентов: 1709. Доля одобренных заявок: 37%
# 3. Московская область, количество выданных патентов: 1211. Доля одобренных заявок: 44%
# 4. Республика Татарстан, количество выданных патентов: 698. Доля одобренных заявок: 100%
# 5. Свердловская область, количество выданных патентов: 475. Доля одобренных заявок: 87%
# 6. Новосибирская область, количество выданных патентов: 401. Доля одобренных заявок: 77%
# 7. Краснодарский край, количество выданных патентов: 398. Доля одобренных заявок: 86%
# 8. Республика Башкортостан, количество выданных патентов: 438. Доля одобренных заявок: 96%
# 9. Воронежская область, количество выданных патентов: 380. Доля одобренных заявок: 88%
# ...
